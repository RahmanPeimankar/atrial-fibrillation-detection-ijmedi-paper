# %% [markdown]
# # (1) Importing/Storing data

# %%
import wfdb
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
records_A = []
properties_A = []
annot_A = []
AnnSymb_A = []
AnnSamp_A = []
AnnRhythm_A = []
Rpeak_Samp_A = []
Rpeak_Symb_A = []


for f in glob.glob('C:/Users/abpe/OneDrive - Syddansk Universitet/SDU/Bachelor-thesis/Masud Shah Jahan/wfdb-python-main-mitdb-afdb-ltafdb-nsrdb/wfdb-python-main-mitdb-afdb-ltafdb-nsrdb/data/arrhythmia_data/*.dat'): ##### change the path to own directory.       
    sig, fields = wfdb.rdsamp(f[:-4], channels=[1])  #### In this function, pass "channels=[0]" or "channels=[1]" to select channel 1 or 2.
    
    ann = wfdb.rdann(f[:-4], 'atr')
    QRS = wfdb.rdann(f[:-4], 'xws')
    Symb = pd.Series(ann.symbol)
    Samp = pd.Series(ann.sample)
    
    QRS_Symb = pd.Series(QRS.symbol)
    QRS_Samp = pd.Series(QRS.sample)
    Rhythm = pd.Series(ann.aux_note)
    records_A.append(sig)
    properties_A.append(fields)
    annot_A.append(ann)
    AnnSymb_A.append(Symb)
    AnnSamp_A.append(Samp)
    Rpeak_Symb_A.append(QRS_Symb)
    Rpeak_Samp_A.append(QRS_Samp)
    AnnRhythm_A.append(Rhythm)
    
    

AnnSymb_A = pd.Series(AnnSymb_A).values
AnnSamp_A = pd.Series(AnnSamp_A).values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6360/2931938977.py in <module>
#      13
#      14     ann = wfdb.rdann(f[:-4], 'atr')
# ---> 15     QRS = wfdb.rdann(f[:-4], 'xws')
#      16     Symb = pd.Series(ann.symbol)
#      17     Samp = pd.Series(ann.sample)
#
# D:\Anaconda\lib\site-packages\wfdb\io\annotation.py in rdann(record_name, extension, sampfrom, sampto, shift_samps, pn_dir, return_label_elements, summarize_labels)
#    1632
#    1633     # Read the file in byte pairs
# -> 1634     filebytes = load_byte_pairs(record_name, extension, pn_dir)
#    1635
#    1636     # Get WFDB annotation fields from the file bytes
#
# D:\Anaconda\lib\site-packages\wfdb\io\annotation.py in load_byte_pairs(record_name, extension, pn_dir)
#    1756     if pn_dir is None:
#    1757         with open(record_name + '.' + extension, 'rb') as f:
# -> 1758             filebytes = np.fromfile(f, '<u1').reshape([-1, 2])
#    1759     # PhysioNet file
#    1760     else:
#
# ValueError: cannot reshape array of size 91 into shape (2)
